# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# %%
# get data files
# !wget https://cdn.freecodecamp.org/project-data/books/book-crossings.zip

# !unzip book-crossings.zip

books_filename = 'BX-Books.csv'
ratings_filename = 'BX-Book-Ratings.csv'
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# import csv data into dataframes
df_books = pd.read_csv(
    books_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['isbn', 'title', 'author'],
    usecols=['isbn', 'title', 'author'],
    dtype={'isbn': 'str', 'title': 'str', 'author': 'str'})

df_ratings = pd.read_csv(
    ratings_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['user', 'isbn', 'rating'],
    usecols=['user', 'isbn', 'rating'],
    dtype={'user': 'int32', 'isbn': 'str', 'rating': 'float32'})

# %%
# add your code here - consider creating a new cell for each section of code
df_books.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author
# 0    Mark P. O. Morford
# 1  Richard Bruce Wright
# 2          Carlo D'Este
# 3      Gina Bari Kolata
# 4       E. J. W. Barber

# %%
df_ratings.head()
# Out:
#      user        isbn  rating
# 0  276725  034545104X     0.0
# 1  276726  0155061224     5.0
# 2  276727  0446520802     0.0
# 3  276729  052165615X     3.0
# 4  276729  0521795028     6.0

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   isbn    271379 non-null  object
#  1   title   271379 non-null  object
#  2   author  271377 non-null  object
# dtypes: object(3)
# memory usage: 6.2+ MB

# %%
df_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   user    1149780 non-null  int32
#  1   isbn    1149780 non-null  object
#  2   rating  1149780 non-null  float32
# dtypes: float32(1), int32(1), object(1)
# memory usage: 17.5+ MB

# %%
df_ratings.user.unique()
# Out:
# array([276725, 276726, 276727, ..., 276709, 276721, 276723], dtype=int32)

# %%
df = df_ratings

counts1 = df['user'].value_counts()
counts2 = df['isbn'].value_counts()


df = df[~df['user'].isin(counts1[counts1 < 200].index)]
# df = df[~df['isbn'].isin(counts2[counts2 < 50].index)]

df = pd.merge(right=df, left = df_books, on="isbn")

df = df.drop_duplicates(["title", "user"])

piv = df.pivot(index='title', columns='user', values='rating').fillna(0)
df
# Out:
#               isbn                                              title  \
# 0       0002005018                                       Clara Callan
# 1       0002005018                                       Clara Callan
# 2       0002005018                                       Clara Callan
# 3       0002005018                                       Clara Callan
# 4       0374157065  Flu: The Story of the Great Influenza Pandemic...
# ...            ...                                                ...
# 488751  0231128444                      Slow Food(The Case For Taste)
# 488752  0520242335  Strong Democracy : Participatory Politics for ...
# 488753  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 488754  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 488755  1845170423                                  Cocktail Classics
#
#                        author    user  rating
# 0        Richard Bruce Wright   11676     8.0
# ...

# %%
matrix = piv.values
matrix.shape
# Out:
# (160587, 905)

# %%
piv
# Out:
# user                                                254     2276    2766    \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Always Have Popsicles                                 0.0     0.0     0.0
#  Apple Magic (The Collector's series)                  0.0     0.0     0.0
#  Beyond IBM: Leadership Marketing and Finance f...     0.0     0.0     0.0
#  Clifford Visita El Hospital (Clifford El Gran ...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ã?Â?ber die Pflicht zum Ungehorsam gegen den St...     0.0     0.0     0.0
# Ã?Â?lpiraten.                                          0.0     0.0     0.0
# Ã?Â?rger mit Produkt X. Roman.                         0.0     0.0     0.0
# Ã?Â?stlich der Berge.                                  0.0     0.0     0.0
# Ã?Â?thique en toc                                      0.0     0.0     0.0
#
# ...

# %%
from sklearn.neighbors import NearestNeighbors
model_knn=NearestNeighbors(metric='cosine',algorithm='brute')
model_knn.fit(matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def get_recommends(book = ""):
  x=piv.loc[book].array.reshape(1, -1)
  distances,indices=model_knn.kneighbors(x,n_neighbors=6)
  R_books=[]
  for distance,indice in zip(distances[0],indices[0]):
    if distance!=0:
      R_book=piv.index[indice]
      R_books.append([R_book,distance])
  recommended_books=[book,R_books[::-1]]
  return recommended_books

# %%
get_recommends('The Metamorphosis (Bantam Classics)')
# Out:
# ['The Metamorphosis (Bantam Classics)', []]

# %%
# Find the row with the specified ISBN
book_title = df_books[df_books['isbn'] == '0684717603']['title'].values

# Print the book title
if len(book_title) > 0:
    print("Book title:", book_title[0])
else:
    print("Book with ISBN 0684717603 not found.")
# Out:
# Book title: The GREAT GATSBY (Scribner Classic)

# %%
books = get_recommends("Where the Heart Is (Oprah's Book Club (Paperback))")
print(books)
